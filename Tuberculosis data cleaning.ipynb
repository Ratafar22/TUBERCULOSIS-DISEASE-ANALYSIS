# %%
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tb = pd.read_excel("TB_burden_countries_2022-08-02.xlsx",0
                )

# %%
tb.head(13)
# Out:
#         country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0   Afghanistan   AF  AFG            4         EMR  2000   20779957
# 1   Afghanistan   AF  AFG            4         EMR  2001   21606992
# 2   Afghanistan   AF  AFG            4         EMR  2002   22600774
# 3   Afghanistan   AF  AFG            4         EMR  2003   23680871
# 4   Afghanistan   AF  AFG            4         EMR  2004   24726689
# 5   Afghanistan   AF  AFG            4         EMR  2005   25654274
# 6   Afghanistan   AF  AFG            4         EMR  2006   26433058
# 7   Afghanistan   AF  AFG            4         EMR  2007   27100542
# 8   Afghanistan   AF  AFG            4         EMR  2008   27722281
# 9   Afghanistan   AF  AFG            4         EMR  2009   28394806
# 10  Afghanistan   AF  AFG            4         EMR  2010   29185511
# 11  Afghanistan   AF  AFG            4         EMR  2011   30117411
# 12  Afghanistan   AF  AFG            4         EMR  2012   31161378
#
# ...

# %%
tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4487 entries, 0 to 4486
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   4487 non-null   object
#  1   iso2                      4466 non-null   object
#  2   iso3                      4487 non-null   object
#  3   iso_numeric               4487 non-null   int64
#  4   g_whoregion               4487 non-null   object
#  5   year                      4487 non-null   int64
#  6   e_pop_num                 4487 non-null   int64
#  7   e_inc_100k                4487 non-null   float64
#  8   e_inc_100k_lo             4487 non-null   float64
#  9   e_inc_100k_hi             4487 non-null   float64
#  10  e_inc_num                 4487 non-null   int64
#  11  e_inc_num_lo              4487 non-null   int64
#  12  e_inc_num_hi              4487 non-null   int64
# ...

# %%
tb.isnull()
# Out:
#       country   iso2   iso3  iso_numeric  g_whoregion   year  e_pop_num  \
# 0       False  False  False        False        False  False      False
# 1       False  False  False        False        False  False      False
# 2       False  False  False        False        False  False      False
# 3       False  False  False        False        False  False      False
# 4       False  False  False        False        False  False      False
# ...       ...    ...    ...          ...          ...    ...        ...
# 4482    False  False  False        False        False  False      False
# 4483    False  False  False        False        False  False      False
# 4484    False  False  False        False        False  False      False
# 4485    False  False  False        False        False  False      False
# 4486    False  False  False        False        False  False      False
#
#       e_inc_100k  e_inc_100k_lo  e_inc_100k_hi  ...    cfr  cfr_lo  cfr_hi  \
# ...

# %%
#rows missing in each column
tb.isnull().sum()
# Out:
# country                        0
# iso2                          21
# iso3                           0
# iso_numeric                    0
# g_whoregion                    0
# year                           0
# e_pop_num                      0
# e_inc_100k                     0
# e_inc_100k_lo                  0
# e_inc_100k_hi                  0
# e_inc_num                      0
# e_inc_num_lo                   0
# e_inc_num_hi                   0
# e_tbhiv_prct                 630
# e_tbhiv_prct_lo              630
# e_tbhiv_prct_hi              630
# e_inc_tbhiv_100k             630
# e_inc_tbhiv_100k_lo          630
# e_inc_tbhiv_100k_hi          630
# e_inc_tbhiv_num              630
# e_inc_tbhiv_num_lo           630
# e_inc_tbhiv_num_hi           630
# e_mort_exc_tbhiv_100k         21
# e_mort_exc_tbhiv_100k_lo      21
# e_mort_exc_tbhiv_100k_hi      21
# e_mort_exc_tbhiv_num          21
# e_mort_exc_tbhiv_num_lo       21
# e_mort_exc_tbhiv_num_hi       21
# ...

# %%
tb.columns
# Out:
# Index(['country', 'iso2', 'iso3', 'iso_numeric', 'g_whoregion', 'year',
#        'e_pop_num', 'e_inc_100k', 'e_inc_100k_lo', 'e_inc_100k_hi',
#        'e_inc_num', 'e_inc_num_lo', 'e_inc_num_hi', 'e_tbhiv_prct',
#        'e_tbhiv_prct_lo', 'e_tbhiv_prct_hi', 'e_inc_tbhiv_100k',
#        'e_inc_tbhiv_100k_lo', 'e_inc_tbhiv_100k_hi', 'e_inc_tbhiv_num',
#        'e_inc_tbhiv_num_lo', 'e_inc_tbhiv_num_hi', 'e_mort_exc_tbhiv_100k',
#        'e_mort_exc_tbhiv_100k_lo', 'e_mort_exc_tbhiv_100k_hi',
#        'e_mort_exc_tbhiv_num', 'e_mort_exc_tbhiv_num_lo',
#        'e_mort_exc_tbhiv_num_hi', 'e_mort_tbhiv_100k', 'e_mort_tbhiv_100k_lo',
#        'e_mort_tbhiv_100k_hi', 'e_mort_tbhiv_num', 'e_mort_tbhiv_num_lo',
#        'e_mort_tbhiv_num_hi', 'e_mort_100k', 'e_mort_100k_lo',
#        'e_mort_100k_hi', 'e_mort_num', 'e_mort_num_lo', 'e_mort_num_hi', 'cfr',
#        'cfr_lo', 'cfr_hi', 'cfr_pct', 'cfr_pct_lo', 'cfr_pct_hi',
#        'c_newinc_100k', 'c_cdr', 'c_cdr_lo', 'c_cdr_hi'],
# ...

# %%
#Drop columns that are not needed
new_dataset= tb.drop(["iso2","iso_numeric","e_inc_100k_lo","e_inc_100k_hi","e_inc_num_lo","e_inc_num_hi","e_tbhiv_prct_lo","e_tbhiv_prct_hi","e_inc_tbhiv_100k_lo","e_inc_tbhiv_100k_hi","e_inc_tbhiv_num_lo","e_inc_tbhiv_num_hi","e_mort_exc_tbhiv_100k_lo","e_mort_exc_tbhiv_100k_hi","e_mort_exc_tbhiv_num_lo","e_mort_exc_tbhiv_num_hi","e_mort_tbhiv_100k_lo","e_mort_tbhiv_100k_hi","e_mort_tbhiv_num_lo","e_mort_tbhiv_num_hi","e_mort_100k_lo","e_mort_100k_hi","e_mort_num_lo","e_mort_num_hi","cfr","cfr_lo","cfr_hi","cfr_pct_lo","cfr_pct_hi","cfr_pct",
"c_cdr_lo","c_cdr_hi"], axis= 1)
display(new_dataset)
# Out:
#           country iso3 g_whoregion  year  e_pop_num  e_inc_100k  e_inc_num  \
# 0     Afghanistan  AFG         EMR  2000   20779957       190.0      39000
# 1     Afghanistan  AFG         EMR  2001   21606992       189.0      41000
# 2     Afghanistan  AFG         EMR  2002   22600774       189.0      43000
# 3     Afghanistan  AFG         EMR  2003   23680871       189.0      45000
# 4     Afghanistan  AFG         EMR  2004   24726689       189.0      47000
# ...           ...  ...         ...   ...        ...         ...        ...
# 4482     Zimbabwe  ZWE         AFR  2016   14030338       233.0      33000
# 4483     Zimbabwe  ZWE         AFR  2017   14236599       221.0      31000
# 4484     Zimbabwe  ZWE         AFR  2018   14438812       210.0      30000
# 4485     Zimbabwe  ZWE         AFR  2019   14645473       199.0      29000
# 4486     Zimbabwe  ZWE         AFR  2020   14862927       193.0      29000
#
# ...

# %%
new_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4487 entries, 0 to 4486
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                4487 non-null   object
#  1   iso3                   4487 non-null   object
#  2   g_whoregion            4487 non-null   object
#  3   year                   4487 non-null   int64
#  4   e_pop_num              4487 non-null   int64
#  5   e_inc_100k             4487 non-null   float64
#  6   e_inc_num              4487 non-null   int64
#  7   e_tbhiv_prct           3857 non-null   float64
#  8   e_inc_tbhiv_100k       3857 non-null   float64
#  9   e_inc_tbhiv_num        3857 non-null   float64
#  10  e_mort_exc_tbhiv_100k  4466 non-null   float64
#  11  e_mort_exc_tbhiv_num   4466 non-null   float64
#  12  e_mort_tbhiv_100k      4466 non-null   float64
#  13  e_mort_tbhiv_num       4466 non-null   float64
# ...

# %%
new_dataset.isnull().sum()
# Out:
# country                    0
# iso3                       0
# g_whoregion                0
# year                       0
# e_pop_num                  0
# e_inc_100k                 0
# e_inc_num                  0
# e_tbhiv_prct             630
# e_inc_tbhiv_100k         630
# e_inc_tbhiv_num          630
# e_mort_exc_tbhiv_100k     21
# e_mort_exc_tbhiv_num      21
# e_mort_tbhiv_100k         21
# e_mort_tbhiv_num          21
# e_mort_100k               21
# e_mort_num                21
# c_newinc_100k            165
# c_cdr                    267
# dtype: int64

# %%
new_Tb_data = new_dataset.fillna(0)

# %%
display(new_Tb_data)
# Out:
#           country iso3 g_whoregion  year  e_pop_num  e_inc_100k  e_inc_num  \
# 0     Afghanistan  AFG         EMR  2000   20779957       190.0      39000
# 1     Afghanistan  AFG         EMR  2001   21606992       189.0      41000
# 2     Afghanistan  AFG         EMR  2002   22600774       189.0      43000
# 3     Afghanistan  AFG         EMR  2003   23680871       189.0      45000
# 4     Afghanistan  AFG         EMR  2004   24726689       189.0      47000
# ...           ...  ...         ...   ...        ...         ...        ...
# 4482     Zimbabwe  ZWE         AFR  2016   14030338       233.0      33000
# 4483     Zimbabwe  ZWE         AFR  2017   14236599       221.0      31000
# 4484     Zimbabwe  ZWE         AFR  2018   14438812       210.0      30000
# 4485     Zimbabwe  ZWE         AFR  2019   14645473       199.0      29000
# 4486     Zimbabwe  ZWE         AFR  2020   14862927       193.0      29000
#
# ...

# %%
new_Tb_data.to_excel('TB_cleaned.xlsx', index= False)
